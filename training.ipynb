# %%
import sagemaker
from sagemaker import get_execution_role
import boto3
import os
from sagemaker.session import Session
from sagemaker.feature_store.feature_group import FeatureGroup
from sklearn.metrics import roc_auc_score

bucket = sagemaker.Session().default_bucket()
prefix = 'sagemaker/TRAINING-xgboost-dm'
# Define IAM role
role = get_execution_role()

# %% [markdown]
# ## Retrieve the data from feature store

# %%
region = boto3.Session().region_name
boto_session = boto3.Session(region_name=region)

sagemaker_client = boto_session.client(service_name='sagemaker', region_name=region)
featurestore_runtime = boto_session.client(service_name='sagemaker-featurestore-runtime', region_name=region)

feature_store_session = Session(
    boto_session=boto_session,
    sagemaker_client=sagemaker_client,
    sagemaker_featurestore_runtime_client=featurestore_runtime
)

feature_group_name = "FG-New-data-flow-20250604-export-5dc2ccd6" 
feature_group = FeatureGroup(name=feature_group_name, sagemaker_session=feature_store_session)

# %%
# Build SQL query to features group
fs_query = feature_group.athena_query()
fs_table = fs_query.table_name
query_string = 'SELECT * FROM "'+fs_table+'"'
print('Running ' + query_string)
# Out:
# Running SELECT * FROM "fg_new_data_flow_20250604_export_5dc2ccd6_1749076781"

# %%
# Run Athena query. The output is loaded to a Pandas dataframe.
fs_query.run(query_string=query_string, output_location='s3://'+bucket+'/'+prefix+'/fs_query_results/')
fs_query.wait()
model_data = fs_query.as_dataframe()
# Out:
# INFO:sagemaker:Query a5f37098-bd34-4a90-adcf-ae7b626f8022 is being executed.
# INFO:sagemaker:Query a5f37098-bd34-4a90-adcf-ae7b626f8022 successfully executed.

# %%
model_data
# Out:
#         custid  retained  ...      api_invocation_time  is_deleted
# 0      19394.0         1  ...  2025-06-04 22:44:58.000       False
# 1      24785.0         1  ...  2025-06-04 22:44:58.000       False
# 2      15390.0         1  ...  2025-06-04 22:44:58.000       False
# 3       7069.0         1  ...  2025-06-04 22:44:58.000       False
# 4      14775.0         0  ...  2025-06-04 22:44:58.000       False
# ...        ...       ...  ...                      ...         ...
# 30796   7437.0         0  ...  2025-06-04 22:45:08.000       False
# 30797   8741.0         0  ...  2025-06-04 22:45:08.000       False
# 30798   6294.0         1  ...  2025-06-04 22:45:08.000       False
# 30799   9204.0         1  ...  2025-06-04 22:45:08.000       False
# 30800  18267.0         1  ...  2025-06-04 22:45:08.000       False
#
# [30801 rows x 24 columns]

# %%
# Prepare data SageMaker's XGBoost
# Amazon SageMaker's XGBoost container expects data in CSV data format.
# Note that the first column must be the target variable and the CSV should not include headers.

# move target (ie, retained) to first column
model_data2 = model_data.reindex(columns = ['retained', 'custid', 'esent', 'eopenrate', 'eclickrate',
                                         'avgorder', 'ordfreq', 'paperless',	'refill', 'doorstep', 
                                            'favday', 'city', 'created_year', 'created_month', 
                                            'created_day', 'firstorder_year', 'firstorder_month',
                                            'firstorder_day', 'lastorder_year', 'lastorder_month', 'lastorder_day'])
model_data2
# Out:
#        retained   custid  esent  ...  lastorder_year  lastorder_month  lastorder_day
# 0             1  19394.0     16  ...          2011.0              6.0           12.0
# 1             1  24785.0     27  ...          2014.0              1.0            5.0
# 2             1  15390.0     35  ...          2012.0              2.0            2.0
# 3             1   7069.0     50  ...          2014.0              1.0            1.0
# 4             0  14775.0      2  ...          2013.0              9.0           16.0
# ...         ...      ...    ...  ...             ...              ...            ...
# 30796         0   7437.0      0  ...          2012.0             11.0           20.0
# 30797         0   8741.0      0  ...          2012.0             10.0            3.0
# 30798         1   6294.0     28  ...          2013.0             11.0           24.0
# 30799         1   9204.0     40  ...          2013.0             11.0           10.0
# 30800         1  18267.0     30  ...          2013.0             11.0            4.0
#
# [30801 rows x 21 columns]

# %%
# remove the headers
model_data2.columns = range(model_data2.shape[1])

model_data2
# Out:
#        0        1   2         3         4   ...    16    17      18    19    20
# 0       1  19394.0  16  0.000000  0.000000  ...   6.0  12.0  2011.0   6.0  12.0
# 1       1  24785.0  27  2.631441  2.104038  ...  11.0   1.0  2014.0   1.0   5.0
# 2       1  15390.0  35  0.289996  0.000000  ...   7.0   9.0  2012.0   2.0   2.0
# 3       1   7069.0  50  0.541325  0.000000  ...  10.0  10.0  2014.0   1.0   1.0
# 4       0  14775.0   2  3.383281  0.000000  ...   9.0  16.0  2013.0   9.0  16.0
# ...    ..      ...  ..       ...       ...  ...   ...   ...     ...   ...   ...
# 30796   0   7437.0   0  0.000000  0.000000  ...  11.0  20.0  2012.0  11.0  20.0
# 30797   0   8741.0   0  0.000000  0.000000  ...  10.0   3.0  2012.0  10.0   3.0
# 30798   1   6294.0  28  1.449978  1.690745  ...  10.0  20.0  2013.0  11.0  24.0
# 30799   1   9204.0  40  2.199133  1.656930  ...  10.0   4.0  2013.0  11.0  10.0
# 30800   1  18267.0  30  0.789432  0.631211  ...  11.0   4.0  2013.0  11.0   4.0
#
# [30801 rows x 21 columns]

# %%
# separate data into train/test data split

# The model will be trained on 70% of data, it will then be evaluated on 20% of data to give us an estimate of the accuracy 
# we hope to have on "new" data, and 10% will be held back as a final testing dataset which will be used later on.


# Compute split indices
train_end = int(0.7 * len(model_data2))
val_end = int(0.9 * len(model_data2))

# Split the DataFrame into train, validation, and test sets
train_data = model_data2.iloc[:train_end]
validation_data = model_data2.iloc[train_end:val_end]
test_data = model_data2.iloc[val_end:]

# %%
# train data to CSV
train_data.to_csv('train.csv', index=False, header=False)
validation_data.to_csv('validation.csv', index=False, header=False)
test_data.to_csv('test.csv', index=False, header=False)

# %%
# copy data to S3 for SageMaker to access
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')).upload_file('validation.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'test/test.csv')).upload_file('validation.csv')

# %% [markdown]
# # Training the Model

# %%
# let's find the ECR container for the current location for Amazon SageMaker's implementation of XGBoost

container = sagemaker.image_uris.retrieve(region=boto3.Session().region_name, framework='xgboost', version='latest')
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.

# %%
# Then, because we're training with the CSV file format, we'll create s3_inputs that our training function can use 
# as a pointer to the files in S3, which also specify that the content type is CSV.
s3_input_train = sagemaker.inputs.TrainingInput(s3_data='s3://{}/{}/train'.format(bucket, prefix), content_type='csv')
s3_input_validation = sagemaker.inputs.TrainingInput(s3_data='s3://{}/{}/validation/'.format(bucket, prefix), content_type='csv')
s3_input_test = sagemaker.inputs.TrainingInput(s3_data='s3://{}/{}/test/'.format(bucket, prefix), content_type='text/csv')

# %%
sess = sagemaker.Session()

xgb = sagemaker.estimator.Estimator(container,
                                    role, 
                                    instance_count=1, 
                                    instance_type='ml.m5.4xlarge',
                                    output_path='s3://{}/{}/output'.format(bucket, prefix),
                                    sagemaker_session=sess)
xgb.set_hyperparameters(max_depth=5, #The maximum depth per tree. A deeper tree might increase the performance, 
                                     #but also the complexity and chances to overfit.
                        eta=0.2, #learning rate
                        gamma=4, #Gamma is a pseudo-regularisation parameter (Lagrangian multiplier), and depends on the other parameters. 
                                 #The higher Gamma is, the higher the regularization.
                        min_child_weight=6,
                        subsample=0.8, #Represents the fraction of observations to be sampled for each tree. 
                                       #A lower values prevent overfitting but might lead to under-fitting.
                        silent=0,
                        objective='reg:linear', #RMSE is the default metric for linear regression; 
                                                #The SageMaker XGBoost algorithm actually calculates RMSE and writes it to the 
                                                #CloudWatch logs on the data passed to the “validation” channel.
                        num_round=100 #number of trees
                       )

xgb.fit({'train': s3_input_train, 'validation': s3_input_validation, 'test': s3_input_test})
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker:Creating training-job with name: xgboost-2025-06-05-02-32-10-571
# 2025-06-05 02:32:11 Starting - Starting the training job...
# 2025-06-05 02:32:45 Downloading - Downloading input data...
# 2025-06-05 02:33:01 Downloading - Downloading the training image...
# 2025-06-05 02:33:36 Training - Training image download completed. Training in progress...Arguments: train
# [2025-06-05:02:33:57:INFO] Running standalone xgboost training.
# [2025-06-05:02:33:57:INFO] File size need to be processed in the node: 3.09mb. Available memory size in the node: 55529.23mb
# [2025-06-05:02:33:57:INFO] Determined delimiter of CSV input is ','
# [02:33:57] S3DistributionType set as FullyReplicated
# [02:33:57] 21560x20 matrix with 431185 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2025-06-05:02:33:57:INFO] Determined delimiter of CSV input is ','
# [02:33:57] S3DistributionType set as FullyReplicated
# [02:33:57] 6160x20 matrix with 123195 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 26 pruned nodes, max_depth=5
# [0]#011train-rmse:0.412076#011validation-rmse:0.412231
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 26 pruned nodes, max_depth=5
# [1]#011train-rmse:0.344127#011validation-rmse:0.344279
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 32 pruned nodes, max_depth=5
# [2]#011train-rmse:0.292517#011validation-rmse:0.292852
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 30 pruned nodes, max_depth=5
# [3]#011train-rmse:0.253615#011validation-rmse:0.254062
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 32 pruned nodes, max_depth=5
# [4]#011train-rmse:0.225072#011validation-rmse:0.225891
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 34 pruned nodes, max_depth=5
# [5]#011train-rmse:0.204562#011validation-rmse:0.205466
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 46 pruned nodes, max_depth=4
# [6]#011train-rmse:0.190979#011validation-rmse:0.191763
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 32 pruned nodes, max_depth=5
# [7]#011train-rmse:0.18022#011validation-rmse:0.181146
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 34 pruned nodes, max_depth=5
# [8]#011train-rmse:0.172813#011validation-rmse:0.173651
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 48 pruned nodes, max_depth=5
# [9]#011train-rmse:0.168051#011validation-rmse:0.168843
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 54 pruned nodes, max_depth=1
# [10]#011train-rmse:0.165482#011validation-rmse:0.166194
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 58 pruned nodes, max_depth=1
# [11]#011train-rmse:0.1638#011validation-rmse:0.164603
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 48 pruned nodes, max_depth=1
# [12]#011train-rmse:0.162669#011validation-rmse:0.163432
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 54 pruned nodes, max_depth=4
# [13]#011train-rmse:0.161548#011validation-rmse:0.162384
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 52 pruned nodes, max_depth=1
# [14]#011train-rmse:0.161058#011validation-rmse:0.161866
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 48 pruned nodes, max_depth=0
# [15]#011train-rmse:0.160936#011validation-rmse:0.161744
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 62 pruned nodes, max_depth=0
# [16]#011train-rmse:0.160861#011validation-rmse:0.161668
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 52 pruned nodes, max_depth=0
# [17]#011train-rmse:0.160811#011validation-rmse:0.161618
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 50 pruned nodes, max_depth=5
# [18]#011train-rmse:0.160055#011validation-rmse:0.160749
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 52 pruned nodes, max_depth=0
# [19]#011train-rmse:0.160038#011validation-rmse:0.160732
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 44 pruned nodes, max_depth=0
# [20]#011train-rmse:0.160022#011validation-rmse:0.160716
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 52 pruned nodes, max_depth=0
# [21]#011train-rmse:0.160013#011validation-rmse:0.160707
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 50 pruned nodes, max_depth=0
# [22]#011train-rmse:0.160008#011validation-rmse:0.160702
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 46 pruned nodes, max_depth=0
# [23]#011train-rmse:0.160002#011validation-rmse:0.160696
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 42 pruned nodes, max_depth=5
# [24]#011train-rmse:0.159216#011validation-rmse:0.159987
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 56 pruned nodes, max_depth=0
# [25]#011train-rmse:0.159216#011validation-rmse:0.159987
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 48 pruned nodes, max_depth=0
# [26]#011train-rmse:0.159215#011validation-rmse:0.159986
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 40 pruned nodes, max_depth=0
# [27]#011train-rmse:0.159214#011validation-rmse:0.159985
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 42 pruned nodes, max_depth=0
# [28]#011train-rmse:0.159214#011validation-rmse:0.159985
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 42 pruned nodes, max_depth=0
# [29]#011train-rmse:0.159213#011validation-rmse:0.159984
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 48 pruned nodes, max_depth=0
# [30]#011train-rmse:0.159213#011validation-rmse:0.159984
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 46 pruned nodes, max_depth=0
# [31]#011train-rmse:0.159213#011validation-rmse:0.159984
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 44 pruned nodes, max_depth=0
# [32]#011train-rmse:0.159213#011validation-rmse:0.159983
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 34 pruned nodes, max_depth=4
# [33]#011train-rmse:0.158726#011validation-rmse:0.159474
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 48 pruned nodes, max_depth=5
# [34]#011train-rmse:0.158131#011validation-rmse:0.158905
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 56 pruned nodes, max_depth=0
# [35]#011train-rmse:0.158131#011validation-rmse:0.158905
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 48 pruned nodes, max_depth=0
# [36]#011train-rmse:0.158131#011validation-rmse:0.158905
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 50 pruned nodes, max_depth=0
# [37]#011train-rmse:0.15813#011validation-rmse:0.158905
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 60 pruned nodes, max_depth=0
# [38]#011train-rmse:0.158131#011validation-rmse:0.158905
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [39]#011train-rmse:0.158131#011validation-rmse:0.158905
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 58 pruned nodes, max_depth=0
# [40]#011train-rmse:0.158131#011validation-rmse:0.158905
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 60 pruned nodes, max_depth=0
# [41]#011train-rmse:0.158131#011validation-rmse:0.158905
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 50 pruned nodes, max_depth=5
# [42]#011train-rmse:0.157561#011validation-rmse:0.158129
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 60 pruned nodes, max_depth=0
# [43]#011train-rmse:0.157561#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [44]#011train-rmse:0.157561#011validation-rmse:0.158129
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 60 pruned nodes, max_depth=0
# [45]#011train-rmse:0.157561#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 46 pruned nodes, max_depth=0
# [46]#011train-rmse:0.157561#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [47]#011train-rmse:0.157561#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 62 pruned nodes, max_depth=0
# [48]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 62 pruned nodes, max_depth=0
# [49]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 56 pruned nodes, max_depth=0
# [50]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 58 pruned nodes, max_depth=0
# [51]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [52]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 50 pruned nodes, max_depth=0
# [53]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 44 pruned nodes, max_depth=0
# [54]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [55]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 50 pruned nodes, max_depth=0
# [56]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 52 pruned nodes, max_depth=0
# [57]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 50 pruned nodes, max_depth=0
# [58]#011train-rmse:0.157561#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 60 pruned nodes, max_depth=0
# [59]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 56 pruned nodes, max_depth=0
# [60]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [61]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 58 pruned nodes, max_depth=0
# [62]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 52 pruned nodes, max_depth=0
# [63]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [64]#011train-rmse:0.157561#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 50 pruned nodes, max_depth=0
# [65]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 60 pruned nodes, max_depth=0
# [66]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [67]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 56 pruned nodes, max_depth=0
# [68]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 56 pruned nodes, max_depth=0
# [69]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 58 pruned nodes, max_depth=0
# [70]#011train-rmse:0.157561#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 60 pruned nodes, max_depth=0
# [71]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 56 pruned nodes, max_depth=0
# [72]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 58 pruned nodes, max_depth=0
# [73]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [74]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 60 pruned nodes, max_depth=0
# [75]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 56 pruned nodes, max_depth=0
# [76]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 56 pruned nodes, max_depth=0
# [77]#011train-rmse:0.157561#011validation-rmse:0.158129
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [78]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 58 pruned nodes, max_depth=0
# [79]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 58 pruned nodes, max_depth=0
# [80]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 58 pruned nodes, max_depth=0
# [81]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [82]#011train-rmse:0.15756#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [83]#011train-rmse:0.157561#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 58 pruned nodes, max_depth=0
# [84]#011train-rmse:0.157561#011validation-rmse:0.158129
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 60 pruned nodes, max_depth=0
# [85]#011train-rmse:0.157561#011validation-rmse:0.158129
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 50 pruned nodes, max_depth=0
# [86]#011train-rmse:0.157561#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 58 pruned nodes, max_depth=0
# [87]#011train-rmse:0.157561#011validation-rmse:0.158129
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 50 pruned nodes, max_depth=0
# [88]#011train-rmse:0.157561#011validation-rmse:0.158128
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 46 pruned nodes, max_depth=5
# [89]#011train-rmse:0.157092#011validation-rmse:0.157606
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [90]#011train-rmse:0.157092#011validation-rmse:0.157606
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 58 pruned nodes, max_depth=0
# [91]#011train-rmse:0.157092#011validation-rmse:0.157606
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 58 pruned nodes, max_depth=0
# [92]#011train-rmse:0.157092#011validation-rmse:0.157606
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 48 pruned nodes, max_depth=0
# [93]#011train-rmse:0.157092#011validation-rmse:0.157605
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [94]#011train-rmse:0.157092#011validation-rmse:0.157605
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [95]#011train-rmse:0.157092#011validation-rmse:0.157606
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 52 pruned nodes, max_depth=0
# [96]#011train-rmse:0.157092#011validation-rmse:0.157606
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 58 pruned nodes, max_depth=0
# [97]#011train-rmse:0.157092#011validation-rmse:0.157605
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 54 pruned nodes, max_depth=0
# [98]#011train-rmse:0.157092#011validation-rmse:0.157605
# [02:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 62 pruned nodes, max_depth=0
# [99]#011train-rmse:0.157092#011validation-rmse:0.157605
#
# 2025-06-05 02:34:15 Uploading - Uploading generated training model
# 2025-06-05 02:34:15 Completed - Training job completed
# Training seconds: 89
# Billable seconds: 89

# %% [markdown]
# # AUC ROC
